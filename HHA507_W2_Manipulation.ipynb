# %% [markdown]
# <a href="https://colab.research.google.com/github/hal-yu/datasci_2_manipulation/blob/main/HHA507_W2_Manipulation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Loading Packages

# %%
import pandas as pd

# %% [markdown]
# ## Load Data
#
# Load the dataset WK2/data/healthcare_data_cleaning.csv in your Colab notebook (preferably one from the previous assignment) OR in a new python script.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/hantswilliams/HHA_507_2023/main/WK2/data/healthcare_data_cleaning.csv')
df
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
# 104999          45  Female      South Jeffrey      Massachusetts
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# ...

# %% [markdown]
# ## Data Cleansing
#
# * Identify and handle missing values in the dataset.
# * Remove any duplicate rows and columns, if they exist.
# * Clean column names
# * Add either a markdown cell if using a notebook, or comments if using a script, to document the changes made to the dataset.

# %% [markdown]
# ### Handling Missing Values in Dataset

# %%
# Check for Missing Values in Columns
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Patient Age                  0
# Gender                       0
# City of Residence            0
# State of Residence           0
# Has Insurance                0
# Visited Last Month           0
# Payment Method               0
# Preferred Doctor             0
# Disease Diagnosed        19993
# Medication Prescribed        0
# Type of Appointment          0
# Average Heart Rate           0
# Average BP                   0
# Height (in cm)               0
# Weight (in kg)               0
# Payment Due ($)              0
# Last Visit (days ago)        0
# Visit Duration (mins)        0
# Number of Tests              0
# Prescription Cost ($)        0
# dtype: int64

# %%
import re
import numpy as np

# %% [markdown]
# ### Identifying and Deleting Duplicate Rows and Columns

# %%
# Identify Duplicate Reecords
print(df.duplicated())
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 104995    False
# 104996    False
# 104997    False
# 104998    False
# 104999     True
# Length: 105000, dtype: bool

# %%
# Removing duplicate rows
df.drop_duplicates(inplace=True)
df
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104994          53  Female      Michelleburgh       South Dakota
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# ...

# %% [markdown]
# ### Cleaning Column Names

# %%
df.columns = df.columns.str.strip()
df
# Out:
#        Patient Age  Gender  City of Residence State of Residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104994          53  Female      Michelleburgh       South Dakota
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
#
#        Has Insurance Visited Last Month Payment Method Preferred Doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# ...

# %% [markdown]
# ### Removing White Space and Special Characters

# %%
# Function to remove white space and special characters from a value
def clean_column_names(data):
  def clean_name(value):
    cleaned_name = re.sub(r'[^a-zA-Z0-9$()]', '_', value)
    return cleaned_name.lower()

# Applying function for all columns
  data.columns = [clean_name(col) for col in data.columns]
  return data

df = clean_column_names(df)

# %%
df
# Out:
#        patient_age  gender  city_of_residence state_of_residence  \
# 0               45   Other         West Brian           Kentucky
# 1               25  Female   East Jocelynfurt           Colorado
# 2               51   Other  South Lindseyland               Ohio
# 3               18  Female         Taylorfort       Pennsylvania
# 4               48  Female          Birdmouth            Montana
# ...            ...     ...                ...                ...
# 104994          53  Female      Michelleburgh       South Dakota
# 104995          74   Other       West Anthony           Oklahoma
# 104996          37    Male          Mckeetown               Utah
# 104997          51  Female   Lake Lisachester           Nebraska
# 104998     missing  Female       Heidiborough            missing
#
#        has_insurance visited_last_month payment_method preferred_doctor  \
# 0                Yes                Yes      Insurance     Dr. Williams
# ...

# %% [markdown]
# ## Data Transformation
#
# * Create new columns based on existing ones (e.g., if you have a 'birth_date' column, create an 'age' column).
# * Aggregate data using groupby and compute summary statistics.
# * Use pivot tables or cross-tabulations for multi-dimensional analysis.

# %% [markdown]
# ### Creating a New Column

# %%
df.dtypes
# Out:
# patient_age              object
# gender                   object
# city_of_residence        object
# state_of_residence       object
# has_insurance            object
# visited_last_month       object
# payment_method           object
# preferred_doctor         object
# disease_diagnosed        object
# medication_prescribed    object
# type_of_appointment      object
# average_heart_rate       object
# average_bp               object
# height_(in_cm)           object
# weight_(in_kg)           object
# payment_due_($)          object
# last_visit_(days_ago)    object
# visit_duration_(mins)    object
# number_of_tests          object
# prescription_cost_($)    object
# dtype: object

# %%
# Convert 'payment_due_(\$)' and 'prescription_cost_(\$)' to numeric values
df['payment_due_($)'] = pd.to_numeric(df['payment_due_($)'], errors='coerce')
df['prescription_cost_($)'] = pd.to_numeric(df['prescription_cost_($)'], errors='coerce')

#Creating New Column called 'NonPrescription_cost'
NonPrescription_cost = (df['payment_due_($)']-df['prescription_cost_($)'])

# %%
NonPrescription_cost
# Out:
# 0          49.739698
# 1         349.897184
# 2         250.678791
# 3         311.427040
# 4         186.731624
#              ...
# 104994    418.489318
# 104995    245.959658
# 104996           NaN
# 104997    285.207998
# 104998   -119.067110
# Length: 100000, dtype: float64

# %% [markdown]
# ### Aggregating Data Using groupby and Compute Summary Statistics

# %%
# Generate descriptive statistics for numerical columns
print(df.describe())
# Out:
#        payment_due_($)  prescription_cost_($)
# count     95000.000000           95000.000000
# mean        249.773034              74.869447
# std         144.496142              43.217415
# min           0.000146               0.014549
# 25%         124.594705              37.573455
# 50%         249.150144              74.620509
# 75%         375.273740             112.202842
# max         499.999999             149.999630

# %%
Payment = df[['has_insurance', 'payment_method', 'payment_due_($)', 'prescription_cost_($)']]
Payment.head(15)
# Out:
#    has_insurance payment_method  payment_due_($)  prescription_cost_($)
# 0            Yes      Insurance        65.457216              15.717517
# 1             No           Card       430.683657              80.786473
# 2            Yes           Cash       315.070931              64.392139
# 3            Yes           Cash       320.299899               8.872859
# 4             No      Insurance       264.214737              77.483113
# 5             No           Card       207.638038              38.565587
# 6             No           Cash              NaN              85.480496
# 7            Yes      Insurance       387.085044              76.965926
# 8             No           Card       172.548343             142.317108
# 9            Yes      Insurance        21.564702              98.416274
# 10           Yes           Cash              NaN             118.211070
# 11            No           Card       299.142676              77.715360
# ...

# %%
Payment.describe()
# Out:
#        payment_due_($)  prescription_cost_($)
# count     95000.000000           95000.000000
# mean        249.773034              74.869447
# std         144.496142              43.217415
# min           0.000146               0.014549
# 25%         124.594705              37.573455
# 50%         249.150144              74.620509
# 75%         375.273740             112.202842
# max         499.999999             149.999630

# %%
# Convert 'patient_age' and 'average_heart_rate' to numeric values
df['patient_age'] = pd.to_numeric(df['patient_age'], errors='coerce')
df['average_heart_rate'] = pd.to_numeric(df['average_heart_rate'], errors='coerce')

bins = [0, 30, 50, np.inf]
labels = ['Young', 'Middle-Aged', 'Senior']

# Creating New Column Called 'age_group'
df['age_group'] = pd.cut(df['patient_age'], bins=bins, labels=labels, right=False)

# %%
df['age_group']
# Out:
# 0         Middle-Aged
# 1               Young
# 2              Senior
# 3               Young
# 4         Middle-Aged
#              ...
# 104994         Senior
# 104995         Senior
# 104996    Middle-Aged
# 104997         Senior
# 104998            NaN
# Name: age_group, Length: 100000, dtype: category
# Categories (3, object): ['Young' < 'Middle-Aged' < 'Senior']

# %%
# Creating Pivot Table1
avg_patient_bp_Pivot = df.pivot_table(values='average_bp', index='gender', columns='age_group', aggfunc='mean')

#Display Pivot Table1
avg_patient_bp_Pivot
# Out:
# age_group       Young  Middle-Aged      Senior
# gender
# Female     109.473592   109.820326  109.674498
# Male       109.333985   109.453390  109.449577
# Other      109.570390   109.673457  109.264606
# missing    109.577236   109.341007  108.985251

# %%
# Creating a Pivot Table2
avg_patient_heart_rate_Pivot = df.pivot_table(values='average_heart_rate', index='gender', columns='age_group', aggfunc='mean')

# Display Pivot Table2
avg_patient_heart_rate_Pivot
# Out:
# age_group      Young  Middle-Aged     Senior
# gender
# Female     79.529617    79.474937  79.410898
# Male       79.403942    79.459206  79.502997
# Other      79.646371    79.550000  79.791432
# missing    79.805930    79.453794  79.711047

# %%
# Creating a Pivot Table3
avg_payment_due_Pivot = df.pivot_table(values='payment_due_($)', index='gender', columns='disease_diagnosed', aggfunc='mean')

# Display Pivot Table3
avg_payment_due_Pivot
# Out:
# disease_diagnosed     Allergy        Cold    Covid-19         Flu     missing
# gender
# Female             244.461234  250.150755  249.788290  247.618356  246.405535
# Male               250.084180  251.060175  250.258525  250.090842  252.896818
# Other              253.060262  247.221839  250.386587  246.463847  255.716219
# missing            256.943468  249.227731  253.443762  253.515655  242.438395

# %%
# Convert 'average_bp' to numeric
df['average_bp'] = pd.to_numeric(df['average_bp'], errors='coerce')

#Group by 'averagebp' based on 'disease_diagnosed'
grouped_data = df.groupby('disease_diagnosed').agg({'average_bp': 'mean'})
print(grouped_data)
# Out:
#                    average_bp
# disease_diagnosed
# Allergy            109.486205
# Cold               109.632230
# Covid-19           109.426924
# Flu                109.493225
# missing            109.330879

# %%
# Convert 'average_heart_rate' to numeric
df['average_heart_rate'] = pd.to_numeric(df['average_heart_rate'], errors='coerce')

#Group by 'average_heart_rate' based on 'disease_diagnosed'
grouped_data2 = df.groupby('disease_diagnosed').agg({'average_heart_rate': 'mean'})
print(grouped_data2)
# Out:
#                    average_heart_rate
# disease_diagnosed
# Allergy                     79.575677
# Cold                        79.575980
# Covid-19                    79.399554
# Flu                         79.540137
# missing                     79.480806

# %% [markdown]
# ## Introduction to Alternative Libraries
#
# * Read about Polars, Dask, and Modin in Chapter 2.
# * Load your dataset using Polars and Modin.
# * Compare the load times and write your observations in a markdown cell or in your script.
# * Please see Chapter 2 - Adv Exercises to see how to use the import time module as an example of capturing start time and end time

# %% [markdown]
# ### Loading Dataset Using Polars and Modin

# %% [markdown]
# #### Load Using Polar

# %%
import polars as pl

# %%
# Load dataset
df2 = pl.read_csv('diabetes.csv')
df2
# Out:
# shape: (768, 9)
# ┌─────────────┬─────────┬───────────────┬───────────────┬───┬──────┬───────────────┬─────┬─────────┐
# │ Pregnancies ┆ Glucose ┆ BloodPressure ┆ SkinThickness ┆ … ┆ BMI  ┆ DiabetesPedig ┆ Age ┆ Outcome │
# │ ---         ┆ ---     ┆ ---           ┆ ---           ┆   ┆ ---  ┆ reeFunction   ┆ --- ┆ ---     │
# │ i64         ┆ i64     ┆ i64           ┆ i64           ┆   ┆ f64  ┆ ---           ┆ i64 ┆ i64     │
# │             ┆         ┆               ┆               ┆   ┆      ┆ f64           ┆     ┆         │
# ╞═════════════╪═════════╪═══════════════╪═══════════════╪═══╪══════╪═══════════════╪═════╪═════════╡
# │ 6           ┆ 148     ┆ 72            ┆ 35            ┆ … ┆ 33.6 ┆ 0.627         ┆ 50  ┆ 1       │
# │ 1           ┆ 85      ┆ 66            ┆ 29            ┆ … ┆ 26.6 ┆ 0.351         ┆ 31  ┆ 0       │
# │ 8           ┆ 183     ┆ 64            ┆ 0             ┆ … ┆ 23.3 ┆ 0.672         ┆ 32  ┆ 1       │
# ...

# %%
# Check Data Type
df2 = pd.read_csv('/content/diabetes.csv')
column_data_type_df2 = df2.dtypes
print(column_data_type_df2)
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
# Remove White Space From Columns Names
df2.columns = df2.columns.str.replace(' ', '')
# Remove All Special Characters With Underscores
df.columns = df.columns.str.replace("[^\w_]", "_")
# Convert All characters to Lowercase
df2.columns = df2.columns.str.lower()
df2.columns
# Out:
# Index(['pregnancies', 'glucose', 'bloodpressure', 'skinthickness', 'insulin',
#        'bmi', 'diabetespedigreefunction', 'age', 'outcome'],
#       dtype='object')

# %%
df2
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      diabetespedigreefunction  age  outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### Loading Using Modin

# %%
pip install "modin[all]"

# %%
import modin.pandas as mpd

# %%
df3 = mpd.read_csv('diabetes.csv')
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Identify Missing Values of Df3
missing_values = df3.isnull().sum()
print(missing_values)
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# Identify Duplicate Rows of Df3
print(df3.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 763    False
# 764    False
# 765    False
# 766    False
# 767    False
# Length: 768, dtype: bool

# %%
# Delete Duplicate Rows of Df3
df3.drop_duplicates(inplace=True)

# %%
# Changing Column Names
df3.columns = df3.columns.str.strip()
df3
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
def clean_column_names(data):
  def clean_name(value):
    cleaned_name = re.sub(r'[^a-zA-Z0-9]', '_', value)
    return cleaned_name.lower()

# Applying function for all columns
  data.columns = [clean_name(col) for col in data.columns]
  return data

df3 = clean_column_names(df3)
df3
# Out:
#      pregnancies  glucose  bloodpressure  skinthickness  insulin   bmi  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      diabetespedigreefunction  age  outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### Observations of Load Times

# %% [markdown]
# * The **polar** data load time was **instant**.
# * The **modin** data also loaded instantly, but it seemed slower than polar

# %% [markdown]
# ### Advanced Exercises

# %%
import pandas as pd
import time

# %%
# Define the dataset path
dataset_path = '/content/diabetes.csv'

# %%
df3 = pd.read_csv('/content/diabetes.csv')
column_data_type_df3 = df3.dtypes
print(column_data_type_df3)
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# #### Check Load Time Without Specific Data

# %%
# Using Pandas
start_time = time.time()
pandas_df3 = pd.read_csv(dataset_path)
pandas_time = time.time() - start_time

# %%
# Using Polar
start_time = time.time()
polar_df3 = pd.read_csv(dataset_path)
polar_time = time.time() - start_time

# %%
# Using Modin
start_time = time.time()
modin_df3 = pd.read_csv(dataset_path)
modin_time = time.time() - start_time

# %%
# Results and Execution Times
print(f"Pandas Execution Time: {pandas_time:.4f} seconds")
print(f"Polar Execution Time: {polar_time:.4f} seconds")
print(f"Modin Execution Time: {modin_time:.4f} seconds")
# Out:
# Pandas Execution Time: 0.0042 seconds
# Polar Execution Time: 0.0027 seconds
# Modin Execution Time: 0.0036 seconds

# %% [markdown]
# #### Check Load Time with Specific Data

# %%
# Using Pandas
start_time = time.time()
pandas_df3 = pd.read_csv(dataset_path)
pandas_filtered = pandas_df3[pandas_df3['Outcome'] == 1]
pandas_average_glucose = pandas_filtered['Glucose'].mean()
pandas_time = time.time() - start_time

# %%
# Using Polar
start_time = time.time()
polar_df3 = pd.read_csv(dataset_path)
polar_filtered = polar_df3[polar_df3['Outcome' ]== 1]
polar_average_glucose = polar_filtered['Glucose'].mean()
polar_time = time.time() - start_time

# %%
# Using Modin
start_time = time.time()
modin_df3 = pd.read_csv(dataset_path)
modin_filtered = modin_df3[modin_df3['Outcome'] == 1]
modin_average_glucose = modin_filtered['Glucose'].mean()
modin_time = time.time() - start_time

# %%
# Results and Execution Times
print(f"Pandas Average Glucose with Positive Outcome: {pandas_average_glucose:.2f} mmol/l")
print(f"Polar Average Glucose with Positive Outcome: {pandas_average_glucose:.2f} mmol/l")
print(f"Modin Average Glucose with Positive Outcome: {modin_average_glucose:.2f} mmol/l")
print(f"Pandas Execution Time: {pandas_time:.4f} seconds")
print(f"Polar Execution Time: {polar_time:.4f} seconds")
print(f"Modin Execution Time: {modin_time:.4f} seconds")
# Out:
# Pandas Average Glucose with Positive Outcome: 141.26 mmol/l
# Polar Average Glucose with Positive Outcome: 141.26 mmol/l
# Modin Average Glucose with Positive Outcome: 141.26 mmol/l
# Pandas Execution Time: 0.0059 seconds
# Polar Execution Time: 0.0053 seconds
# Modin Execution Time: 0.0055 seconds

# %% [markdown]
# #### Summary of Load Times
#
# * The load time at this point of text, the polar load time was the fastest, then modin, then pandas.
# * Previous time done, modin was generally fastest, then polar, then pandas.
